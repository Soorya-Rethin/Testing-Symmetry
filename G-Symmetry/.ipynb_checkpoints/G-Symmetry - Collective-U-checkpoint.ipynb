# %%
import math
import random
import numpy as np
from itertools import product

from qiskit import *

# Importing standard Qiskit libraries
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from qiskit.providers.aer import QasmSimulator

import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

from qiskit.utils import QuantumInstance

from qiskit.opflow import I, X, Y, Z
from qiskit.opflow import StateFn
from qiskit.opflow import Gradient
from qiskit.opflow import CircuitSampler
from qiskit.opflow.primitive_ops import MatrixOp

from qiskit.circuit import Parameter
from qiskit.circuit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import RealAmplitudes

from qiskit.algorithms.optimizers import SPSA
from qiskit.algorithms.optimizers import GradientDescent

from qiskit.extensions.unitary import UnitaryGate
from qiskit.circuit.library.standard_gates import CZGate
from qiskit.circuit.library.standard_gates import CRYGate
from qiskit.circuit.library.standard_gates import CHGate
from qiskit.circuit.library.standard_gates import HGate
from qiskit.circuit.library.standard_gates import XGate
from qiskit.circuit.library.standard_gates import RXGate
from qiskit.circuit.library.standard_gates import RYGate
from qiskit.circuit.library.standard_gates import RZGate
from qiskit.providers.aer.noise import NoiseModel

from qiskit.quantum_info import Statevector
from qiskit.ignis.mitigation.measurement import CompleteMeasFitter

# %%
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-09-01 02:00:54,579: Credentials are already in use. The existing account in the session will be replaced.

# %%
def rand_numb(low_in,high_in):
    return np.random.uniform(low=low_in, high=np.nextafter(high_in, np.inf))

#just to keep the upper limit included in the random number generation.

# %%
def append(list1, list2):
    temp = []
    temp.extend(list1)
    temp.extend(list2)
    return temp

# %%
def createActual(x, L):
    temp = []
    for i in range(L):
        temp = np.append(temp, x)
    return temp

# %%
numLayer = 4
numQubit = 2
global iterations
global noisy

# %%
def Bx():
    temp = QuantumCircuit(2)
    temp.append(RXGate(-np.pi/2), [0])
    temp.append(RXGate(-np.pi/2), [1])
    return temp

# %%
def By():
    temp = QuantumCircuit(2)
    temp.append(RYGate(-np.pi/2), [0])
    temp.append(RYGate(-np.pi/2), [1])
    return temp

# %%
def Bz():
    temp = QuantumCircuit(2)
    temp.append(RZGate(-np.pi/2), [0])
    temp.append(RZGate(-np.pi/2), [1])
    return temp

# %%
def Bxb():
    temp = QuantumCircuit(2)
    temp.append(RXGate(np.pi/2), [0])
    temp.append(RXGate(np.pi/2), [1])
    return temp

# %%
def Byb():
    return By()

# %%
def Bzb():
    temp = QuantumCircuit(2)
    temp.append(RZGate(np.pi/2), [0])
    temp.append(RZGate(np.pi/2), [1])
    return temp

# %%
#Create unitaries here
#unitary_param_1 = np.array([])
#for i in range(0, 16):
#    unitary_param_1 = np.append(unitary_param_1, np.array([rand_numb(0,2*np.pi)]))

unitary_param_1 = np.array([5.40530723, 0.30789834, 5.48565623, 5.49679285, 5.58904428, 3.67626375,
                            5.38444934, 0.19679063, 6.16917933, 0.2308673,  5.04796852, 6.02401649,
                            0.93282454, 4.6738944,  3.02576907, 2.90214658])

print(unitary_param_1)
# Out:
# [5.40530723 0.30789834 5.48565623 5.49679285 5.58904428 3.67626375
#  5.38444934 0.19679063 6.16917933 0.2308673  5.04796852 6.02401649
#  0.93282454 4.6738944  3.02576907 2.90214658]

# %%
def createProver(numQubit, numLayer):
    numparam = numQubit*numLayer*2
    prover = QuantumCircuit(numQubit)
    param_vector = ParameterVector("params", numparam)
    
    for j in range(numLayer):
        for i in range(numQubit):
            prover.rx(param_vector[j*2*numQubit + i], i)
            prover.ry(param_vector[j*2*numQubit + i + numQubit], i)

        for i in range(numQubit-1):
            prover.cx(i, i+1)
            
    return prover

# %%
size = 4
layers = 2
state = QuantumCircuit(size)
for j in range(layers):
    for i in range(size):
        state.rx(unitary_param_1[j*size*2 + i], i)
        state.ry(unitary_param_1[j*2*size + i + size], i)

    for i in range(size-1):
        state.cx(i, i+1)

state.draw('mpl')

# %%
qcTest = QuantumCircuit(4)
qcTest.x(0)
qcTest.draw('mpl')

# %%
def createEqSuperposCollectiveU():
    temp = QuantumCircuit(5)
    
    temp.ry(2*np.arctan(1/np.sqrt(2)), 1)
    temp.x(1)
    temp.append(CHGate(), [1, 0])
    temp.x(1)
    
    temp.ry(np.pi/3, 2)
    temp.x(2)
    temp.append(CRYGate(2*np.arctan(1/np.sqrt(2))), [2, 3])
    temp.x(3)
    temp.append(HGate().control(2), [2, 3, 4])
    temp.x(2)
    temp.x(3)
    return temp

# %%
def createQuantumCircuit():
    circ = QuantumCircuit(9)
    #Create Quantum Circuit here
    
    superPosCircuit = createEqSuperposCollectiveU()
    circ.append(superPosCircuit, [0, 1, 2, 3, 4])
    circ.append(qcTest, [5, 6, 7, 8])

    prover = createProver(numQubit, numLayer)
    circ.append(prover, [7, 8])
    
    circ.barrier()
    
    circ.append(Bx().control(1), [4, 5, 6])
    circ.append(Bxb().control(1), [4, 7, 8])
    circ.append(Bx().control(1), [4, 5, 6])
    circ.append(Bxb().control(1), [4, 7, 8])
    
    circ.append(By().control(1), [3, 5, 6])
    circ.append(Byb().control(1), [3, 7, 8])
    circ.append(By().control(1), [3, 5, 6])
    circ.append(Byb().control(1), [3, 7, 8])

    circ.append(Bz().control(1), [2, 5, 6])
    circ.append(Bzb().control(1), [2, 7, 8])
    circ.append(Bz().control(1), [2, 5, 6])
    circ.append(Bzb().control(1), [2, 7, 8])
    
    circ.append(By().control(1), [1, 5, 6])
    circ.append(Byb().control(1), [1, 7, 8])
    circ.append(Bx().control(1), [1, 5, 6])
    circ.append(Bxb().control(1), [1, 7, 8])
    
    circ.append(Bx().control(1), [0, 5, 6])
    circ.append(Bxb().control(1), [0, 7, 8])
    circ.append(By().control(1), [0, 5, 6])
    circ.append(Byb().control(1), [0, 7, 8])

    circ.append(superPosCircuit.inverse(), range(5))
    
    return circ

# %%
qCirc = createQuantumCircuit()
qCirc.draw('mpl')

# %%
#use if noiseless
noiseless_backend = Aer.get_backend('statevector_simulator')
noiseless_q_instance = QuantumInstance(noiseless_backend)
noiseless_sampler = CircuitSampler(noiseless_q_instance)

# %%
'''
Pick a backend to use. We use the qasm_simulator for noisy simulation. 
'''
#Replace the provider with your personal credentials for hub, group and main
provider = IBMQ.get_provider(hub="ibm-q-research", group="louisiana-st-uni-1", project="main")

noisy_backend = Aer.get_backend("qasm_simulator")
device = provider.get_backend("ibmq_jakarta")
coupling_map = device.configuration().coupling_map
noise_model = NoiseModel.from_backend(device.properties())
noisy_q_instance = QuantumInstance(backend=noisy_backend, 
                           shots=8192, 
                           noise_model=noise_model, 
                           coupling_map=coupling_map,
                           measurement_error_mitigation_cls=CompleteMeasFitter,
                           cals_matrix_refresh_period=30)
noisy_sampler = CircuitSampler(noisy_q_instance)

# %%
#Create Hamiltonian here
hamiltonian = I^I^I^I^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))

# %%
def costf(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    
    if noisy:
        result = noisy_sampler.convert(expectation, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(expectation, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
def gradient(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    gradient = Gradient().convert(expectation)
    
    if noisy:
        result = noisy_sampler.convert(gradient, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(gradient, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
print(qCirc.parameters)
# Out:
# ParameterView([ParameterVectorElement(params[0]), ParameterVectorElement(params[1]), ParameterVectorElement(params[2]), ParameterVectorElement(params[3]), ParameterVectorElement(params[4]), ParameterVectorElement(params[5]), ParameterVectorElement(params[6]), ParameterVectorElement(params[7]), ParameterVectorElement(params[8]), ParameterVectorElement(params[9]), ParameterVectorElement(params[10]), ParameterVectorElement(params[11]), ParameterVectorElement(params[12]), ParameterVectorElement(params[13]), ParameterVectorElement(params[14]), ParameterVectorElement(params[15])])

# %%
def autospsa_callback(nfev, x, fx, stepsize, accepted = False):
    loss.append(-1*fx)
    print("Loss Value : ", -1*fx, str(nfev/3)+"%")

# %%
loss = []
noisy = False
numParam = 2*numQubit*numLayer

paramProver = []
for i in range(0, numParam):
    paramProver = np.append(paramProver, np.array([rand_numb(0,2*np.pi)]))
print(paramProver)

print("Initial Cost : ", -1*costf(paramProver))
# Out:
# [2.15358698 6.01305764 2.0981613  4.33747792 2.18405068 6.10312853
#  0.6272313  2.80444234 0.00716066 1.1482935  4.86907342 5.61437678
#  5.06167679 1.58590158 2.0691164  6.11010973]
# Initial Cost :  0.15044294889050444

# %%
autospsa = SPSA(maxiter=250, learning_rate=0.1, perturbation=0.1, callback=autospsa_callback)
x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=paramProver)

#autospsa = GradientDescent(maxiter=100, learning_rate=0.1, callback=autospsa_callback)
#x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=x_opt)
# Out:
# Loss Value :  0.1521227750280004 1.0%
# Loss Value :  0.153511143451999 2.0%
# Loss Value :  0.1558647253993113 3.0%
# Loss Value :  0.19300031042983018 4.0%
# Loss Value :  0.19891527512745005 5.0%
# Loss Value :  0.20562717430302369 6.0%
# Loss Value :  0.2056563685609027 7.0%
# Loss Value :  0.23046950527043908 8.0%
# Loss Value :  0.2528292150338545 9.0%
# Loss Value :  0.2639955159852585 10.0%
# Loss Value :  0.2657982436655359 11.0%
# Loss Value :  0.26584616804915884 12.0%
# Loss Value :  0.276446610703597 13.0%
# Loss Value :  0.2766536677593756 14.0%
# Loss Value :  0.28966041659314756 15.0%
# Loss Value :  0.29712395843604894 16.0%
# Loss Value :  0.3324524985711379 17.0%
# Loss Value :  0.3325235390493519 18.0%
# Loss Value :  0.335642103244336 19.0%
# Loss Value :  0.3370115488914158 20.0%
# Loss Value :  0.3410661243235594 21.0%
# Loss Value :  0.34139828341946427 22.0%
# Loss Value :  0.3503753053271802 23.0%
# Loss Value :  0.3526902943391037 24.0%
# Loss Value :  0.365399124181641 25.0%
# Loss Value :  0.377482299949639 26.0%
# Loss Value :  0.39026615795860714 27.0%
# Loss Value :  0.3984735365752195 28.0%
# Loss Value :  0.4094027058781356 29.0%
# Loss Value :  0.4416839660226642 30.0%
# Loss Value :  0.44278348303959164 31.0%
# Loss Value :  0.4456326283392052 32.0%
# Loss Value :  0.4464859796361133 33.0%
# Loss Value :  0.44873134117910124 34.0%
# Loss Value :  0.4571347768404617 35.0%
# Loss Value :  0.4572936439414399 36.0%
# Loss Value :  0.45932215745762267 37.0%
# Loss Value :  0.4622289461645998 38.0%
# Loss Value :  0.47325881595565644 39.0%
# Loss Value :  0.4733524922776079 40.0%
# Loss Value :  0.47624893208432073 41.0%
# Loss Value :  0.47683377764623625 42.0%
# Loss Value :  0.4768432789689185 43.0%
# Loss Value :  0.48467702335732415 44.0%
# Loss Value :  0.48518969575523646 45.0%
# Loss Value :  0.4852459502835313 46.0%
# Loss Value :  0.4869580958412664 47.0%
# Loss Value :  0.48720588691396455 48.0%
# Loss Value :  0.4872298985192705 49.0%
# Loss Value :  0.4872465936084022 50.0%
# Loss Value :  0.48782708595268914 51.0%
# Loss Value :  0.48965859561343994 52.0%
# Loss Value :  0.4908967907675107 53.0%
# Loss Value :  0.49093912021915453 54.0%
# Loss Value :  0.4909627105415774 55.0%
# Loss Value :  0.491039480034949 56.0%
# Loss Value :  0.4911169507435899 57.0%
# Loss Value :  0.4919461713207096 58.0%
# Loss Value :  0.49241111755906586 59.0%
# Loss Value :  0.4925572733360829 60.0%
# Loss Value :  0.4926615821818502 61.0%
# Loss Value :  0.4927482966299638 62.0%
# Loss Value :  0.49292703739431354 63.0%
# Loss Value :  0.4932519339619313 64.0%
# Loss Value :  0.49331843009564713 65.0%
# Loss Value :  0.49331907442230605 66.0%
# Loss Value :  0.4933169197042688 67.0%
# Loss Value :  0.4939398090069298 68.0%
# Loss Value :  0.49436209178570983 69.0%
# Loss Value :  0.4958379859315738 70.0%
# Loss Value :  0.49583879784783663 71.0%
# Loss Value :  0.49598002115371503 72.0%
# Loss Value :  0.49620913148443785 73.0%
# Loss Value :  0.4963131661966259 74.0%
# Loss Value :  0.4963910224241618 75.0%
# Loss Value :  0.496416660721473 76.0%
# Loss Value :  0.4964209110291794 77.0%
# Loss Value :  0.496627136622169 78.0%
# Loss Value :  0.49663162112303194 79.0%
# Loss Value :  0.4970882438417526 80.0%
# Loss Value :  0.49710436328812946 81.0%
# Loss Value :  0.49723048167716455 82.0%
# Loss Value :  0.49725339342527236 83.0%
# Loss Value :  0.49732258314341826 84.0%
# Loss Value :  0.49749714802919465 85.0%
# Loss Value :  0.4977341658591259 86.0%
# Loss Value :  0.49795684578893984 87.0%
# Loss Value :  0.49805599832935793 88.0%
# Loss Value :  0.49838252177302605 89.0%
# Loss Value :  0.4984121919185735 90.0%
# Loss Value :  0.4984285373512166 91.0%
# Loss Value :  0.4984216844203152 92.0%
# Loss Value :  0.49850643518198634 93.0%
# Loss Value :  0.49851217131291015 94.0%
# Loss Value :  0.4986612189965994 95.0%
# Loss Value :  0.498799038097727 96.0%
# Loss Value :  0.4988471359278036 97.0%
# Loss Value :  0.4988469676054859 98.0%
# Loss Value :  0.4988448909689243 99.0%
# Loss Value :  0.49890608505459083 100.0%
# Loss Value :  0.4989304388539676 101.0%
# Loss Value :  0.4989340347822766 102.0%
# Loss Value :  0.49896955891299916 103.0%
# Loss Value :  0.49896918003446616 104.0%
# Loss Value :  0.49898534754371704 105.0%
# Loss Value :  0.4989842557682395 106.0%
# Loss Value :  0.4991303549848808 107.0%
# Loss Value :  0.4991583013952356 108.0%
# Loss Value :  0.4991585765551875 109.0%
# Loss Value :  0.499162202757782 110.0%
# Loss Value :  0.4991787268936031 111.0%
# Loss Value :  0.49920729602807895 112.0%
# Loss Value :  0.49925168641330514 113.0%
# Loss Value :  0.49924765421044626 114.0%
# Loss Value :  0.49924742187444465 115.0%
# Loss Value :  0.49937072690474965 116.0%
# Loss Value :  0.49939215656671454 117.0%
# Loss Value :  0.49939489747820076 118.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-39cf24614a90> in <module>
#       1 autospsa = SPSA(maxiter=250, learning_rate=0.1, perturbation=0.1, callback=autospsa_callback)
# ----> 2 x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=paramProver)
#       3
#       4 #autospsa = GradientDescent(maxiter=100, learning_rate=0.1, callback=autospsa_callback)
#       5 #x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=x_opt)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     554         initial_point=None,
#     555     ):
# --> 556         return self._minimize(objective_function, initial_point)
#     557
#     558
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _minimize(self, loss, initial_point)
#     467             iteration_start = time()
#     468             # compute update
# --> 469             update = self._compute_update(loss, x, k, next(eps), lse_solver)
#     470
#     471             # trust region
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _compute_update(self, loss, x, k, eps, lse_solver)
#     409
#     410         # accumulate the number of samples
# --> 411         gradient, hessian = self._point_estimate(loss, x, eps, num_samples)
#     412
#     413         # precondition gradient with inverse Hessian, if specified
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _point_estimate(self, loss, x, eps, num_samples)
#     393             delta2 = deltas2[i] if self.second_order else None
#     394
# --> 395             gradient_sample, hessian_sample = self._point_sample(loss, x, eps, delta1, delta2)
#     396             gradient_estimate += gradient_sample
#     397
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _point_sample(self, loss, x, eps, delta1, delta2)
#     355
#     356         # batch evaluate the points (if possible)
# --> 357         values = _batch_evaluate(loss, points, self._max_evals_grouped)
#     358
#     359         plus = values[0]
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in _batch_evaluate(function, points, max_evals_grouped)
#     592     if max_evals_grouped == 1:
#     593         # support functions with multiple arguments where the points are given in a tuple
# --> 594         return [
#     595             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     596         ]
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/algorithms/optimizers/spsa.py in <listcomp>(.0)
#     593         # support functions with multiple arguments where the points are given in a tuple
#     594         return [
# --> 595             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     596         ]
#     597
#
# <ipython-input-113-b477b8d8b775> in costf(params)
#       6         result = noisy_sampler.convert(expectation, params=value_dict).eval()
#       7     else:
# ----> 8         result = noiseless_sampler.convert(expectation, params=value_dict).eval()
#       9
#      10     return -1*np.real(result)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/opflow/converters/circuit_sampler.py in convert(self, operator, params)
#     216         circs = list(self._circuit_ops_cache.values()) if not self._transpiled_circ_cache else None
#     217         p_b = cast(List[Dict[Parameter, float]], param_bindings)
# --> 218         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs, param_bindings=p_b)
#     219
#     220         def replace_circuits_with_dicts(operator, param_index=0):
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/opflow/converters/circuit_sampler.py in sample_circuits(self, circuit_sfns, param_bindings)
#     297
#     298             try:
# --> 299                 self._transpiled_circ_cache = self.quantum_instance.transpile(circuits)
#     300             except QiskitError:
#     301                 logger.debug(
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/utils/quantum_instance.py in transpile(self, circuits)
#     343             transpiled_circuits = self._pass_manager.run(circuits)
#     344         else:
# --> 345             transpiled_circuits = compiler.transpile(
#     346                 circuits, self._backend, **self._backend_config, **self._compile_config
#     347             )
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/compiler/transpiler.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     291
#     292     # Transpile circuits in parallel
# --> 293     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     294
#     295     end_time = time()
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     130         return []
#     131     if len(values) == 1:
# --> 132         return [task(values[0], *task_args, **task_kwargs)]
#     133
#     134     Publisher().publish("terra.parallel.start", len(values))
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/compiler/transpiler.py in _transpile_circuit(circuit_config_tuple)
#     378         raise TranspilerError("optimization_level can range from 0 to 3.")
#     379
# --> 380     result = pass_manager.run(
#     381         circuit, callback=transpile_config["callback"], output_name=transpile_config["output_name"]
#     382     )
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/passmanager.py in run(self, circuits, output_name, callback)
#     214         """
#     215         if isinstance(circuits, QuantumCircuit):
# --> 216             return self._run_single_circuit(circuits, output_name, callback)
#     217         elif len(circuits) == 1:
#     218             return self._run_single_circuit(circuits[0], output_name, callback)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     270         """
#     271         running_passmanager = self._create_running_passmanager()
# --> 272         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     273         self.property_set = running_passmanager.property_set
#     274         return result
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py in run(***failed resolving arguments***)
#     121         for passset in self.working_list:
#     122             for pass_ in passset:
# --> 123                 dag = self._do_pass(pass_, dag, passset.options)
#     124
#     125         circuit = dag_to_circuit(dag)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     152         # Run the pass itself, if not already run
#     153         if pass_ not in self.valid_passes:
# --> 154             dag = self._run_this_pass(pass_, dag)
#     155
#     156             # update the valid_passes property
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     164             # Measure time if we have a callback or logging set
#     165             start_time = time()
# --> 166             new_dag = pass_.run(dag)
#     167             end_time = time()
#     168             run_time = end_time - start_time
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py in run(self, dag)
#      92                 operator = gate.op.to_matrix().dot(operator)
#      93             for decomposer in self._decomposers:
# ---> 94                 new_circs.append(decomposer._decompose(operator))
#      95             if new_circs:
#      96                 new_circ = min(new_circs, key=len)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/synthesis/one_qubit_decompose.py in _decompose(self, unitary, simplify, atol)
#     165
#     166     def _decompose(self, unitary, simplify=True, atol=DEFAULT_ATOL):
# --> 167         theta, phi, lam, phase = self._params(unitary)
#     168         circuit = self._circuit(theta, phi, lam, phase, simplify=simplify, atol=atol)
#     169         return circuit
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/quantum_info/synthesis/one_qubit_decompose.py in _params_zyz(mat)
#     232         # U[1, 0] = exp(i(phi-lambda)/2) * sin(theta/2)
#     233         # U[1, 1] = exp(i(phi+lambda)/2) * cos(theta/2)
# --> 234         theta = 2 * math.atan2(abs(su_mat[1, 0]), abs(su_mat[0, 0]))
#     235         phiplambda2 = cmath.phase(su_mat[1, 1])
#     236         phimlambda2 = cmath.phase(su_mat[1, 0])
#
# KeyboardInterrupt:

# %%
print(-1*fx_opt)
print(x_opt)

# %%
def plot_loss():
    start_point = 0
    plt.figure(figsize=(12, 6))
    plt.plot(createActual(0.5000000028507108, len(loss[start_point:])), label = 'Actual')
    plt.plot(loss[start_point:], 'tab:green', label='Loss')
    plt.ylabel('Acceptance Probability')
    plt.xlabel('iterations')
    plt.legend()
    plt.show()
plot_loss()
