# %%
import math
import random
import numpy as np
from itertools import product

from qiskit import *

# Importing standard Qiskit libraries
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from qiskit.providers.aer import QasmSimulator

import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

from qiskit.utils import QuantumInstance

from qiskit.opflow import I, X, Y, Z
from qiskit.opflow import StateFn
from qiskit.opflow import Gradient
from qiskit.opflow import CircuitSampler
from qiskit.opflow.primitive_ops import MatrixOp

from qiskit.circuit import Parameter
from qiskit.circuit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import RealAmplitudes

from qiskit.algorithms.optimizers import SPSA
from qiskit.algorithms.optimizers import GradientDescent
from qiskit.algorithms.optimizers import ADAM

from qiskit.extensions.unitary import UnitaryGate
from qiskit.circuit.library.standard_gates import CZGate
from qiskit.circuit.library.standard_gates import CHGate
from qiskit.circuit.library.standard_gates import SGate

from qiskit.providers.aer.noise import NoiseModel

from qiskit.quantum_info import Statevector
from qiskit.ignis.mitigation.measurement import CompleteMeasFitter

# %%
provider = IBMQ.load_account()

# %%
def rand_numb(low_in,high_in):
    return np.random.uniform(low=low_in, high=np.nextafter(high_in, np.inf))

#just to keep the upper limit included in the random number generation.

# %%
numLayer = 3
numQubit = 5
global iterations
global noisy

# %%
#Create unitaries here
unitary_param_1 = np.array([])
for i in range(0, 12):
    unitary_param_1 = np.append(unitary_param_1, np.array([rand_numb(0,2*np.pi)]))

unitary_param_1 = [4.76597606, 4.47050986, 4.19269861, 3.72124531, 4.94472091, 1.61563712,
                   3.44120060, 3.24526326, 0.91836107, 1.32971456, 4.80863498, 0.54593609]

# %%
print(unitary_param_1)
# Out:
# [4.76597606, 4.47050986, 4.19269861, 3.72124531, 4.94472091, 1.61563712, 3.4412006, 3.24526326, 0.91836107, 1.32971456, 4.80863498, 0.54593609]

# %%
# First unitary
size = 3
layers = 2
state = QuantumCircuit(size)
for j in range(layers):
    for i in range(size):
        state.rx(unitary_param_1[j*size*2 + i], i)
        state.ry(unitary_param_1[j*2*size + i + size], i)

    for i in range(size-1):
        state.cx(i, i+1)

state.draw('mpl')

# %%
def createProver(numQubit, numLayer):
    numparam = numQubit*numLayer*2
    prover = QuantumCircuit(numQubit)
    param_vector = ParameterVector("params", numparam)
    
    for j in range(numLayer):
        for i in range(numQubit):
            prover.rx(param_vector[j*2*numQubit + i], i)
            prover.ry(param_vector[j*2*numQubit + i + numQubit], i)

        for i in range(numQubit-1):
            prover.cx(i, i+1)
            
    return prover

# %%
def createEqSuperposCollectiveZSE():
    temp = QuantumCircuit(2)
    temp.h(0)
    temp.h(1)
    return temp

# %%
qcTest = QuantumCircuit(3)
qcTest.rx(np.pi/4, 0)
qcTest.ry(np.pi/4, 0)
qcTest.rx(np.pi/4, 1)
qcTest.ry(np.pi/4, 1)
qcTest.cx(0, 1)
qcTest.draw('mpl')

# %%
def createQuantumCircuit(state, numQubit, numLayer):
    circ = QuantumCircuit(8)
    #Create Quantum Circuit here
    
    superPosCircuit = createEqSuperposCollectiveZSE()
    circ.append(superPosCircuit, [0, 1])

    circ.append(state, [2, 3, 4])
    
    prover = createProver(numQubit, numLayer)
    circ.append(prover, [3, 4, 5, 6, 7])
    
    circ.barrier()
    controlledU1 = SGate().control(1)
    controlledU1b = SGate().inverse().control(1)
    
    circ.append(controlledU1, [1, 2])
    circ.append(controlledU1, [1, 3])
    circ.append(controlledU1, [1, 4])
    
    circ.append(controlledU1b, [1, 5])
    circ.append(controlledU1b, [1, 6])
    circ.append(controlledU1b, [1, 7])
    
    circ.append(CZGate(), [0, 2])
    circ.append(CZGate(), [0, 3])
    circ.append(CZGate(), [0, 4])

    circ.append(CZGate(), [0, 5])
    circ.append(CZGate(), [0, 6])
    circ.append(CZGate(), [0, 7])
    
    circ.append(superPosCircuit.inverse(), [0, 1])
    
    return circ

# %%
qCirc = createQuantumCircuit(qcTest, numQubit, numLayer)
qCirc.draw('mpl')

# %%
#use if noiseless
noiseless_backend = Aer.get_backend('statevector_simulator')
noiseless_q_instance = QuantumInstance(noiseless_backend)
noiseless_sampler = CircuitSampler(noiseless_q_instance)

# %%
#Use if noisy
provider = IBMQ.get_provider(hub="ibm-q-research", group="louisiana-st-uni-1", project="main")
noisy_backend = Aer.get_backend("qasm_simulator")
device = provider.get_backend("ibm_lagos")
coupling_map = device.configuration().coupling_map
noise_model = NoiseModel.from_backend(device.properties())
noisy_q_instance = QuantumInstance(backend=noisy_backend, 
                           shots=8192, 
                           noise_model=noise_model, 
                           coupling_map=coupling_map,
                           measurement_error_mitigation_cls=CompleteMeasFitter,
                           cals_matrix_refresh_period=30)
noisy_sampler = CircuitSampler(noisy_q_instance)

# %%
#Create Hamiltonian here
hamiltonian = I^I^I^I^I^I^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))

# %%
def costf(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    
    if noisy:
        result = noisy_sampler.convert(expectation, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(expectation, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
def gradient(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    gradient = Gradient().convert(expectation)
    
    if noisy:
        result = noisy_sampler.convert(gradient, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(gradient, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
print(qCirc.parameters)
# Out:
# ParameterView([ParameterVectorElement(params[0]), ParameterVectorElement(params[1]), ParameterVectorElement(params[2]), ParameterVectorElement(params[3]), ParameterVectorElement(params[4]), ParameterVectorElement(params[5]), ParameterVectorElement(params[6]), ParameterVectorElement(params[7]), ParameterVectorElement(params[8]), ParameterVectorElement(params[9]), ParameterVectorElement(params[10]), ParameterVectorElement(params[11]), ParameterVectorElement(params[12]), ParameterVectorElement(params[13]), ParameterVectorElement(params[14]), ParameterVectorElement(params[15]), ParameterVectorElement(params[16]), ParameterVectorElement(params[17]), ParameterVectorElement(params[18]), ParameterVectorElement(params[19]), ParameterVectorElement(params[20]), ParameterVectorElement(params[21]), ParameterVectorElement(params[22]), ParameterVectorElement(params[23]), ParameterVectorElement(params[24]), ParameterVectorElement(params[25]), ParameterVectorElement(params[26]), ParameterVectorElement(params[27]), ParameterVectorElement(params[28]), ParameterVectorElement(params[29])])

# %%
def autospsa_callback(nfev, x, fx, stepsize, accepted = False):
    if (noisy == True):
        noisy_loss.append(-1*fx)
    else:
        noiseless_loss.append(-1*fx)
    print("Loss Value : ", -1*fx, str(nfev/3)+"%")

# %%
numParam = 2*numQubit*numLayer
noisy = False
paramProver = []
for i in range(0, numParam):
    paramProver = np.append(paramProver, np.array([rand_numb(0,2*np.pi)]))
print(paramProver)

print("Initial Cost : ", -1*costf(paramProver))
# Out:
# [3.69681101 1.42786811 1.62395111 4.24309695 3.43107112 0.42636405
#  5.52933328 1.95547931 3.69150398 5.33858289 5.70702099 4.54198486
#  3.41332308 0.95510959 3.74701067 4.68085166 1.71875344 1.03657668
#  1.5832799  0.42896113 3.93304791 4.77179386 2.94633749 4.4754494
#  5.16505082 6.06259509 4.41162918 5.73328015 1.535693   3.6660174 ]
# Initial Cost :  0.30272770196494153

# %%
true_value = 0.9507

# %%
noisy = False
noiseless_loss = []
noiselessParam = np.copy(paramProver)
print("Initial Cost : ", -1*costf(noiselessParam))
autospsa = SPSA(maxiter=400, learning_rate=None, perturbation=None, callback=autospsa_callback)
x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=noiselessParam)
# Out:
# Initial Cost :  0.30272770196494153
# Loss Value :  0.2971553765635791 1.0%
# Loss Value :  0.15024824372634227 2.0%
# Loss Value :  0.22462521689175088 3.0%
# Loss Value :  0.22308576752651638 4.0%
# Loss Value :  0.3059513805111951 5.0%
# Loss Value :  0.3110958937027209 6.0%
# Loss Value :  0.36372856901273154 7.0%
# Loss Value :  0.3732726762373566 8.0%
# Loss Value :  0.38982917482331275 9.0%
# Loss Value :  0.3900557010435459 10.0%
# Loss Value :  0.38907140783558947 11.0%
# Loss Value :  0.3952413018664442 12.0%
# Loss Value :  0.3954996224998141 13.0%
# Loss Value :  0.3977619075046436 14.0%
# Loss Value :  0.4368433175937989 15.0%
# Loss Value :  0.4413994098267317 16.0%
# Loss Value :  0.44194531402658577 17.0%
# Loss Value :  0.44234777363434297 18.0%
# Loss Value :  0.44379350829350384 19.0%
# Loss Value :  0.4467305442845626 20.0%
# Loss Value :  0.44679927753364135 21.0%
# Loss Value :  0.46084709776552407 22.0%
# Loss Value :  0.4638380138329117 23.0%
# Loss Value :  0.4671742804385835 24.0%
# Loss Value :  0.4585028980810415 25.0%
# Loss Value :  0.4831820809557331 26.0%
# Loss Value :  0.505000078087168 27.0%
# Loss Value :  0.5212056709466828 28.0%
# Loss Value :  0.5203381065043021 29.0%
# Loss Value :  0.520155022754681 30.0%
# Loss Value :  0.5203906232551029 31.0%
# Loss Value :  0.5153037525762991 32.0%
# Loss Value :  0.5161629665250032 33.0%
# Loss Value :  0.5318727130033513 34.0%
# Loss Value :  0.5562764161697747 35.0%
# Loss Value :  0.5587621342315673 36.0%
# Loss Value :  0.5864561614057706 37.0%
# Loss Value :  0.5850011543761532 38.0%
# Loss Value :  0.5905792986930218 39.0%
# Loss Value :  0.5828829098892551 40.0%
# Loss Value :  0.5964009792686515 41.0%
# Loss Value :  0.6095141179601258 42.0%
# Loss Value :  0.5957454160325463 43.0%
# Loss Value :  0.6141915374830185 44.0%
# Loss Value :  0.6204961150856056 45.0%
# Loss Value :  0.62059350217504 46.0%
# Loss Value :  0.6543966172515003 47.0%
# Loss Value :  0.6571807648853906 48.0%
ospsa = SPSA(maxiter=200, learning_rate=None, perturbation=None, callback=autospsa_callback)
x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=noisyParam)
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# <ipython-input-25-65d8abf05af5> in <module>
#       2 noisy_loss = []
#       3 noisyParam = np.copy(paramProver)
# ----> 4 -1*costf(noisyParam)
#       5 print("Initial Cost : ", -1*costf(noisyParam))
#       6 autospsa = SPSA(maxiter=200, learning_rate=None, perturbation=None, callback=autospsa_callback)
#
# <ipython-input-18-b477b8d8b775> in costf(params)
#       4
#       5     if noisy:
# ----> 6         result = noisy_sampler.convert(expectation, params=value_dict).eval()
#       7     else:
#       8         result = noiseless_sampler.convert(expectation, params=value_dict).eval()
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/opflow/converters/circuit_sampler.py in convert(self, operator, params)
#     216         circs = list(self._circuit_ops_cache.values()) if not self._transpiled_circ_cache else None
#     217         p_b = cast(List[Dict[Parameter, float]], param_bindings)
# --> 218         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs, param_bindings=p_b)
#     219
#     220         def replace_circuits_with_dicts(operator, param_index=0):
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/opflow/converters/circuit_sampler.py in sample_circuits(self, circuit_sfns, param_bindings)
#     327             ready_circs = self._transpiled_circ_cache
#     328
# --> 329         results = self.quantum_instance.execute(
#     330             ready_circs, had_transpiled=self._transpile_before_bind
#     331         )
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/utils/quantum_instance.py in execute(self, circuits, had_transpiled)
#     396         # maybe compile
#     397         if not had_transpiled:
# --> 398             circuits = self.transpile(circuits)
#     399
#     400         from qiskit.providers import BackendV1
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/utils/quantum_instance.py in transpile(self, circuits)
#     343             transpiled_circuits = self._pass_manager.run(circuits)
#     344         else:
# --> 345             transpiled_circuits = compiler.transpile(
#     346                 circuits, self._backend, **self._backend_config, **self._compile_config
#     347             )
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/compiler/transpiler.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     288     )
#     289
# --> 290     _check_circuits_coupling_map(circuits, transpile_args, backend)
#     291
#     292     # Transpile circuits in parallel
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/compiler/transpiler.py in _check_circuits_coupling_map(circuits, transpile_args, backend)
#     328
#     329         if max_qubits is not None and (num_qubits > max_qubits):
# --> 330             raise TranspilerError(
#     331                 f"Number of qubits ({num_qubits}) in {circuit.name} "
#     332                 f"is greater than maximum ({max_qubits}) in the coupling_map"
#
# TranspilerError: 'Number of qubits (8) in circuit-48472 is greater than maximum (7) in the coupling_map'

# %%
noisy = False
noiseResilientValue = -1*costf(x_opt)
print(noiseResilientValue)
# Out:
# 0.7408891258900123

# %%
print("True Value : ", true_value)
print("Noiseless : ", noiseless_loss[-1])
#print("Noisy : ", noisy_loss[-1])
#print("Noise Resilient Value : ", noiseResilientValue)
# Out:
# True Value :  0.9507
# Noiseless :  0.9500365380886749

# %%
def writeToFile():
    file = open("CZ_GSE.txt", "w+")
    file.write(str(true_value)+"\n")
    file.write(str(true_value)+"\n")

    file.write(str(len(noiseless_loss))+"\n")
    L = [str(i)+"\n" for i in noiseless_loss]
    file.writelines(L)
    
    file.write(str(len(noiseless_loss))+"\n")
    L = [str(i)+"\n" for i in noiseless_loss[0:len(noiseless_loss)-1]]
    file.writelines(L)
    
    file.write(str(noiseless_loss[-1]))
    
    file.close()

# %%
writeToFile()
