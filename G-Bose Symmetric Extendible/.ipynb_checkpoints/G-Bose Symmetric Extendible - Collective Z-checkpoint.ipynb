# %%
import math
import random
import numpy as np
from itertools import product

from qiskit import *

# Importing standard Qiskit libraries
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from qiskit.providers.aer import QasmSimulator

import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

from qiskit.utils import QuantumInstance

from qiskit.opflow import I, X, Y, Z
from qiskit.opflow import StateFn
from qiskit.opflow import Gradient
from qiskit.opflow import CircuitSampler
from qiskit.opflow.primitive_ops import MatrixOp
from qiskit.extensions.unitary import UnitaryGate
from qiskit.circuit.library.standard_gates import CZGate
from qiskit.circuit.library.standard_gates import SGate

from qiskit.circuit import Parameter
from qiskit.circuit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import RealAmplitudes

from qiskit.algorithms.optimizers import SPSA
from qiskit.algorithms.optimizers import GradientDescent
from qiskit.algorithms.optimizers import ADAM

from qiskit.providers.aer.noise import NoiseModel

from qiskit.quantum_info import Statevector
from qiskit.ignis.mitigation.measurement import CompleteMeasFitter

# %%
provider = IBMQ.load_account()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# --> 953     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fda60497790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/api/session.py in increment(self, method, url, response, error, _pool, _stacktrace)
#      96                          method, url, status, error, data, headers)
# ---> 97         return super().increment(method=method, url=url, response=response,
#      98                                  error=error, _pool=_pool, _stacktrace=_stacktrace)
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/version (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda60497790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/api/session.py in request(self, method, url, bare, **kwargs)
#     276             self._log_request_info(url, method, kwargs)
# --> 277             response = super().request(method, final_url, headers=headers, **kwargs)
#     278             response.raise_for_status()
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/version (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda60497790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# <ipython-input-2-0f43e831b340> in <module>
# ----> 1 provider = IBMQ.load_account()
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/ibmqfactory.py in load_account(self)
#     175         # Explicitly check via a server call, to allow environment auth URLs
#     176         # contain IBM Quantum Experience v2 URL (but not auth) slipping through.
# --> 177         version_info = self._check_api_version(credentials)
#     178
#     179         # Check the URL is a valid authentication URL.
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/ibmqfactory.py in _check_api_version(credentials)
#     442         version_finder = VersionClient(credentials.base_url,
#     443                                        **credentials.connection_parameters())
# --> 444         return version_finder.version()
#     445
#     446     def _initialize_providers(
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/api/clients/version.py in version(self)
#      47                 * ``api-*`` (str): The versions of each individual API component
#      48         """
# ---> 49         return self.client_version_finder.version()
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/api/rest/root.py in version(self)
#     100         """
#     101         url = self.get_url('version')
# --> 102         response = self.session.get(url)
#     103
#     104         try:
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/api/session.py in request(self, method, url, bare, **kwargs)
#     298                 self._modify_chained_exception_messages(ex)
#     299
# --> 300             raise RequestsApiError(message, status_code) from ex
#     301
#     302         return response
#
# RequestsApiError: "HTTPSConnectionPool(host='auth.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/version (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda60497790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))"

# %%
def rand_numb(low_in,high_in):
    return np.random.uniform(low=low_in, high=np.nextafter(high_in, np.inf))

#just to keep the upper limit included in the random number generation.

# %%
def append(list1, list2):
    temp = []
    temp.extend(list1)
    temp.extend(list2)
    return temp

# %%
def createActual(x, L):
    temp = []
    for i in range(L):
        temp = np.append(temp, x)
    return temp

# %%
numLayer = 2
numQubit = 1
global iterations
global noisy

# %%
#Create unitaries here
unitary_param_1 = np.array([])
for i in range(0, 12):
    unitary_param_1 = np.append(unitary_param_1, np.array([rand_numb(0,2*np.pi)]))

unitary_param_1 = [4.76597606, 4.47050986, 4.19269861, 3.72124531, 4.94472091, 1.61563712,
                   3.44120060, 3.24526326, 0.91836107, 1.32971456, 4.80863498, 0.54593609]

# %%
print(unitary_param_1)
# Out:
# [4.76597606, 4.47050986, 4.19269861, 3.72124531, 4.94472091, 1.61563712, 3.4412006, 3.24526326, 0.91836107, 1.32971456, 4.80863498, 0.54593609]

# %%
# First unitary
size = 3
layers = 2
state = QuantumCircuit(size)
for j in range(layers):
    for i in range(size):
        state.rx(unitary_param_1[j*size*2 + i], i)
        state.ry(unitary_param_1[j*2*size + i + size], i)

    for i in range(size-1):
        state.cx(i, i+1)

state.draw('mpl')

# %%
def createProver(numQubit, numLayer):
    numparam = numQubit*numLayer*2
    prover = QuantumCircuit(numQubit)
    param_vector = ParameterVector("params", numparam)
    
    for j in range(numLayer):
        for i in range(numQubit):
            prover.rx(param_vector[j*2*numQubit + i], i)
            prover.ry(param_vector[j*2*numQubit + i + numQubit], i)

        for i in range(numQubit-1):
            prover.cx(i, i+1)
            
    return prover

# %%
def createEqSuperposCollectiveZBSE():
    temp = QuantumCircuit(2)
    temp.h(0)
    temp.h(1)
    return temp

# %%
qcTest = QuantumCircuit(3)
qcTest.ry(np.pi/3, 0)
qcTest.cx(0, 1)
qcTest.ry(np.pi/6, 2)
qcTest.cx(2, 0)
qcTest.draw('mpl')

# %%
def createQuantumCircuit(numQubit, numLayer):
    circ = QuantumCircuit(5)
    #Create Quantum Circuit here
    
    superPosCircuit = createEqSuperposCollectiveZBSE()
    circ.append(superPosCircuit, [0, 1])

    circ.append(qcTest, [2, 3, 4])
    
    prover = createProver(numQubit, numLayer)
    circ.append(prover, [4])
    
    controlledU1 = SGate().control(1)
    circ.append(controlledU1, [1, 2])
    circ.append(controlledU1, [1, 3])
    circ.append(controlledU1, [1, 4])
    
    circ.append(CZGate(), [0, 2])
    circ.append(CZGate(), [0, 3])
    circ.append(CZGate(), [0, 4])
    
    circ.append(superPosCircuit.inverse(), [0, 1])
    
    return circ

# %%
qCirc = createQuantumCircuit(numQubit, numLayer)
qCirc.draw('mpl')
# Out:
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/circuit/tools/pi_check.py:55: SymPyDeprecationWarning:
#
# The expr_free_symbols property is deprecated. Use free_symbols to get
# the free symbols of an expression.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-expr-free-symbols
# for details.
#
# This has been deprecated since SymPy version 1.9. It
# will be removed in a future version of SymPy.
#
#   syms = expr.expr_free_symbols

# %%
#use if noiseless
noiseless_backend = Aer.get_backend('statevector_simulator')
noiseless_q_instance = QuantumInstance(noiseless_backend)
noiseless_sampler = CircuitSampler(noiseless_q_instance)

# %%
#Use if noisy
provider = IBMQ.get_provider(hub="ibm-q-research", group="louisiana-st-uni-1", project="main")
noisy_backend = Aer.get_backend("qasm_simulator")
device = provider.get_backend("ibmq_lima")
coupling_map = device.configuration().coupling_map
noise_model = NoiseModel.from_backend(device.properties())
noisy_q_instance = QuantumInstance(backend=noisy_backend, 
                           shots=8192, 
                           noise_model=noise_model, 
                           coupling_map=coupling_map,
                           measurement_error_mitigation_cls=CompleteMeasFitter,
                           cals_matrix_refresh_period=30)
noisy_sampler = CircuitSampler(noisy_q_instance)
# Out:
# ---------------------------------------------------------------------------
# IBMQProviderError                         Traceback (most recent call last)
# <ipython-input-19-3fe1ba711215> in <module>
#       1 #Use if noisy
# ----> 2 provider = IBMQ.get_provider(hub="ibm-q-research", group="louisiana-st-uni-1", project="main")
#       3 noisy_backend = Aer.get_backend("qasm_simulator")
#       4 device = provider.get_backend("ibmq_lima")
#       5 coupling_map = device.configuration().coupling_map
#
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/qiskit/providers/ibmq/ibmqfactory.py in get_provider(self, hub, group, project)
#     421
#     422         if not providers:
# --> 423             raise IBMQProviderError('No provider matches the specified criteria: '
#     424                                     'hub = {}, group = {}, project = {}'
#     425                                     .format(hub, group, project))
#
# IBMQProviderError: 'No provider matches the specified criteria: hub = ibm-q-research, group = louisiana-st-uni-1, project = main'

# %%
#Create Hamiltonian here
hamiltonian = I^I^I^MatrixOp(np.array([[1, 0], [0, 0]]))^MatrixOp(np.array([[1, 0], [0, 0]]))

# %%
def costf(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    
    if noisy:
        result = noisy_sampler.convert(expectation, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(expectation, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
def gradient(params):
    expectation = StateFn(hamiltonian, is_measurement=True).compose(StateFn(qCirc))
    value_dict = dict(zip(qCirc.parameters, params))
    gradient = Gradient().convert(expectation)
    
    if noisy:
        result = noisy_sampler.convert(gradient, params=value_dict).eval()  
    else:
        result = noiseless_sampler.convert(gradient, params=value_dict).eval()  
    
    return -1*np.real(result)

# %%
print(qCirc.parameters)
# Out:
# ParameterView([ParameterVectorElement(params[0]), ParameterVectorElement(params[1]), ParameterVectorElement(params[2]), ParameterVectorElement(params[3])])

# %%
def autospsa_callback(nfev, x, fx, stepsize, accepted = False):
    if (noisy == True):
        noisy_loss.append(-1*fx)
    else:
        noiseless_loss.append(-1*fx)
    print("Loss Value : ", -1*fx, str(nfev/3)+"%")

# %%
numParam = 2*numQubit*numLayer
noisy = False
paramProver = []
for i in range(0, numParam):
    paramProver = np.append(paramProver, np.array([rand_numb(0,2*np.pi)]))
print(paramProver)

print(-1*costf(paramProver))
# Out:
# [1.96580082 1.2512563  3.27429988 0.23145679]
# 0.46159671475965003

# %%
true_value = 0.7045622350098858

# %%
noisy = False
noiseless_loss = []
noiselessParam = np.copy(paramProver)
print("Initial Cost : ", -1*costf(noiselessParam))
autospsa = SPSA(maxiter=100, learning_rate=0.1, perturbation=0.1, callback=autospsa_callback)
x_opt, fx_opt, nfevs = autospsa.optimize(numParam, costf, initial_point=noiselessParam)
# Out:
# Initial Cost :  0.46159671475965003
# Loss Value :  0.4809432480428377 1.0%
# Loss Value :  0.48287382932737005 2.0%
# Loss Value :  0.49610170186516434 3.0%
# Loss Value :  0.5172819536245251 4.0%
# Loss Value :  0.5561231983085023 5.0%
# Loss Value :  0.5735060705331789 6.0%
# Loss Value :  0.5747878616357286 7.0%
# Loss Value :  0.5753794622947073 8.0%
# Loss Value :  0.5768318918588756 9.0%
# Loss Value :  0.5915465632152911 10.0%
# Loss Value :  0.6033343473921154 11.0%
# Loss Value :  0.6309825586883955 12.0%
# Loss Value :  0.6312049645266593 13.0%
# Loss Value :  0.6371865625858298 14.0%
# Loss Value :  0.6421270888000632 15.0%
# Loss Value :  0.6599450806995488 16.0%
# Loss Value :  0.6727926316548949 17.0%
# Loss Value :  0.6749665446521608 18.0%
# Loss Value :  0.6797341230481514 19.0%
# Loss Value :  0.6811808755739002 20.0%
# Loss Value :  0.6826467863314528 21.0%
# Loss Value :  0.6828143036118278 22.0%
# Loss Value :  0.6884087340539687 23.0%
# Loss Value :  0.6884963659943135 24.0%
# Loss Value :  0.6885796244392158 25.0%
# Loss Value :  0.6886766150372772 26.0%
# Loss Value :  0.6906860345429535 27.0%
# Loss Value :  0.6907098040408345 28.0%
# Loss Value :  0.6914067132537796 29.0%
# Loss Value :  0.6920003339234138 30.0%
# Loss Value :  0.6924005525493746 31.0%
# Loss Value :  0.6924128598742991 32.0%
# Loss Value :  0.6927839141688069 33.0%
# Loss Value :  0.6938451412307215 34.0%
# Loss Value :  0.6946072177745878 35.0%
# Loss Value :  0.6946080428450842 36.0%
# Loss Value :  0.6951451775038512 37.0%
# Loss Value :  0.6951628308830818 38.0%
# Loss Value :  0.6967364838057171 39.0%
# Loss Value :  0.6972717159517234 40.0%
# Loss Value :  0.6973051860483103 41.0%
# Loss Value :  0.6973381592687626 42.0%
# Loss Value :  0.6975319609947045 43.0%
# Loss Value :  0.6977479388877476 44.0%
# Loss Value :  0.6977748407756215 45.0%
# Loss Value :  0.6977811280510684 46.0%
# Loss Value :  0.6977922839709203 47.0%
# Loss Value :  0.6981327191593523 48.0%
# Loss Value :  0.6981548328601561 49.0%
# Loss Value :  0.701059813626818 81.0%
# Loss Value :  0.7073058626762374 82.0%
# Loss Value :  0.7002897133355778 83.0%
# Loss Value :  0.6914277183710495 84.0%
# Loss Value :  0.6946354204919286 85.0%
# Loss Value :  0.6938503407526232 86.0%
# Loss Value :  0.6893537032343346 87.0%
# Loss Value :  0.6946685685868439 88.0%
# Loss Value :  0.6943914879835408 89.0%
# Loss Value :  0.6832643010713033 90.0%
# Loss Value :  0.6999146811888868 91.0%
# Loss Value :  0.6994804877250511 92.0%
# Loss Value :  0.6958210415600621 93.0%
# Loss Value :  0.7018917840983034 94.0%
# Loss Value :  0.6907967272804759 95.0%
# Loss Value :  0.6876829674034688 96.0%
# Loss Value :  0.6859219420954344 97.0%
# Loss Value :  0.7086981890647447 98.0%
# Loss Value :  0.6898704611205877 99.0%
# Loss Value :  0.7012316696440812 100.0%

# %%
noisy = False
noiseResilientValue = -1*costf(x_opt)
print(noiseResilientValue)
# Out:
# 0.699258230795588

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter, LogLocator
from matplotlib import rcParams
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.ticker as ticker
from matplotlib import rc

c1 = '#14A76C'
c6 = '#AC3B61'
c4 = '#2B7A78'
c2 = '#2E9CCA'
c5 = '#29648A'
c3 = '#F76C6C'

l1 = "#1f77b4"
l2 = "#d62728"
l3 = "#2ca02c"
l4 = "#ff7f0e"

#m,c,k,g,r,b

#plt.rcParams['text.usetex'] = True
timesfont = {'fontname':'Times'}
style.use('seaborn-ticks')

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
# Plot and show our data
ax.plot(noiseless_loss,'-o', markersize=3, markevery=2, color = l1, linewidth=0.7, label = 'Noiseless Simulator')
ax.plot(noisy_loss,'-o', markersize=3, markevery=1, color = l2, linewidth=0.7, label = 'Noisy Simulator')
ax.plot(createActual(true_value, len(noiseless_loss)),'-p', markersize=5, markevery=5, color = l3, linewidth=1, label = 'True Value')
ax.plot(createActual(noiseResilientValue, len(noiseless_loss)),'-p', markersize=5, markevery=10, color = l4, linewidth=1, label = 'Final noisy parameters on noiseless simulator')


#ax.set_xscale('log')
#ax.set_xlim(0, 1600)

ax.grid(b=True, which='major', color='#666666', linestyle='--',alpha=0.4)
ax.legend(loc=0)
ax.set_xlabel('Iterations',**timesfont,fontsize =18)
ax.set_ylabel('Acceptance Probability',**timesfont,fontsize =18)
plt.savefig("GBSE-CollectiveZ-qcTest.pdf", dpi=2000, format='pdf', bbox_extra_artists=(), bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-58-44e9c42186ba>:49: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig("GBSE-CollectiveZ-qcTest.pdf", dpi=2000, format='pdf', bbox_extra_artists=(), bbox_inches='tight')
# <ipython-input-58-44e9c42186ba>:49: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig("GBSE-CollectiveZ-qcTest.pdf", dpi=2000, format='pdf', bbox_extra_artists=(), bbox_inches='tight')
# /opt/anaconda3/envs/qiskit/lib/python3.9/site-packages/IPython/core/pylabtools.py:134: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
